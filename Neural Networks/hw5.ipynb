# %%
#From SAV to LOVE

# %% [markdown]
# # HW4

# %% [markdown]
# Попробуйте обучить нейронную сеть LSTM на любом другом датасете (любимый временной ряд, текст на русском (другом языке) как генератор или классификатор, или прилагаемый набор airline-passengers - пасажиропоток для авиалиний). Опишите, какой результата вы получили? Что помогло вам улучшить ее точность?

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-1bc5dcd7-5819-4e1a-b93e-d02621b28261" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bc5dcd7-5819-4e1a-b93e-d02621b28261">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wells_war_of_the_worlds.txt to wells_war_of_the_worlds.txt
# {'wells_war_of_the_worlds.txt': b'The War of the Worlds\r\n\r\nby H. G. Wells [1898]\r\n\r\n\r\n     But who shall dwell in these worlds if they be\r\n     inhabited? .  .  .  Are we or they Lords of the\r\n     World? .  .  .  And how are all things made for man?--\r\n          KEPLER (quoted in The Anatomy of Melancholy)\r\n\r\n\r\n\r\nBOOK ONE\r\n\r\nTHE COMING OF THE MARTIANS\r\n\r\n\r\n\r\nCHAPTER ONE\r\n\r\nTHE EVE OF THE WAR\r\n\r\n\r\nNo one would have believed in the last years of the nineteenth\r\ncentury that this world was being watched keenly and closely by\r\nintelligences greater than man\'s and yet as mortal as his own; that as\r\nmen busied themselves about their various concerns they were\r\nscrutinised and studied, perhaps almost as narrowly as a man with a\r\nmicroscope might scrutinise the transient creatures that swarm and\r\nmultiply in a drop of water.  With infinite complacency men went to\r\nand fro over this globe about their little affairs, serene in their\r\nassurance of their empire over matter.  It is possible that the\r\ninfusoria under the microscope do the same.  No one gave a thought to\r\nthe older worlds of space as sources of human danger, or thought of\r\nthem only to dismiss the idea of life upon them as impossible or\r\nimprobable.  It is curious to recall some of the mental habits of\r\nthose departed days.  At most terrestrial men fancied there might be\r\nother men upon Mars, perhaps inferior to themselves and ready to\r\nwelcome a missionary enterprise.  Yet across the gulf of space, minds\r\nthat are to our minds as ours are to those of the beasts that perish,\r\nintellects vast and cool and unsympathetic, regarded this earth with\r\nenvious eyes, and slowly and surely drew their plans against us.  And\r\nearly in the twentieth century came the great disillusionment.\r\n\r\nThe planet Mars, I scarcely need remind the reader, revolves about the\r\nsun at a mean distance of 140,000,000 miles, and the light and heat it\r\nreceives from the sun is barely half of that received by this world.\r\nIt must be, if the nebular hypothesis has any truth, older than our\r\nworld; and long before this earth ceased to be molten, life upon its\r\nsurface must have begun its course.  The fact that it is scarcely one\r\nseventh of the volume of the earth must have accelerated its cooling\r\nto the temperature at which life could begin.  It has air and water\r\nand all that is necessary for the support of animated existence.\r\n\r\nYet so vain is man, and so blinded by his vanity, that no writer,\r\nup to the very end of the nineteenth century, expressed any idea that\r\nintelligent life might have developed there far, or indeed at all,\r\nbeyond its earthly level.  Nor was it generally understood that since\r\nMars is older than our earth, with scarcely a quarter of the\r\nsuperficial area and remoter from the sun, it necessarily follows that\r\nit is not only more distant from time\'s beginning but nearer its end.\r\n\r\nThe secular cooling that must someday overtake our planet has\r\nalready gone far indeed with our neighbour.  Its physical condition is\r\nstill largely a mystery, but we know now that even in its equatorial\r\nregion the midday temperature barely approaches that of our coldest\r\nwinter.  Its air is much more attenuated than ours, its oceans have\r\nshrunk until they cover but a third of its surface, and as its slow\r\nseasons change huge snowcaps gather and melt about either pole and\r\nperiodically inundate its temperate zones.  That last stage of\r\nexhaustion, which to us is still incredibly remote, has become a\r\npresent-day problem for the inhabitants of Mars.  The immediate\r\npressure of necessity has brightened their intellects, enlarged their\r\npowers, and hardened their hearts.  And looking across space with\r\ninstruments, and intelligences such as we have scarcely dreamed of,\r\nthey see, at its nearest distance only 35,000,000 of miles sunward of\r\nthem, a morning  ...

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential


# построчное чтение из примера с текстом 
with open("wells_war_of_the_worlds.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 1 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100


# Create a super simple recurrent neural network. There is one recurrent
# layer that produces an embedding of size HIDDEN_SIZE from the one-hot
# encoded input layer. This is followed by a Dense fully-connected layer
# across the set of possible next characters, which is converted to a
# probability score via a standard softmax activation with a multi-class
# cross-entropy loss function linking the prediction to the one-hot
# encoding character label.

'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой. За ним последует полносвязный слой связанный с набором возможных следующих символов, которые конвертированы в вероятностные результаты через стандартную softmax активацию с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''

model = Sequential()
model.add(
    LSTM(  # вы можете изменить эту часть на GRU, LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# ==================================================
# Итерация #: 0
# 2643/2643 [==============================] - 82s 30ms/step - loss: 2.4971
# Генерация из посева: ater crept
# ater crepter and the rear the rear the rear the rear the rear the rear the rear the rear the rear the rear the

# %% [markdown]
# ***Качество генерации соминтельное, только первые несколько слов***

# %% [markdown]
# ### Увеличим кол-во символов для отбора c 10 до 50

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential


# построчное чтение из примера с текстом 
with open("wells_war_of_the_worlds.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10-50 символов 
SEQLEN, STEP = 50, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 1 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100


# Create a super simple recurrent neural network. There is one recurrent
# layer that produces an embedding of size HIDDEN_SIZE from the one-hot
# encoded input layer. This is followed by a Dense fully-connected layer
# across the set of possible next characters, which is converted to a
# probability score via a standard softmax activation with a multi-class
# cross-entropy loss function linking the prediction to the one-hot
# encoding character label.

'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой. За ним последует полносвязный слой связанный с набором возможных следующих символов, которые конвертированы в вероятностные результаты через стандартную softmax активацию с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''

model = Sequential()
model.add(
    LSTM(  # вы можете изменить эту часть на GRU, LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# ==================================================
# Итерация #: 0
# 2642/2642 [==============================] - 381s 141ms/step - loss: 2.4875
# Генерация из посева: ining these renderings had a considerable vogue, a
# ining these renderings had a considerable vogue, and the roud the roud the roud the roud the roud the roud the roud the roud the roud the roud the rou

# %% [markdown]
# # Вывод:
# Текст на выходе стал более содержателльным, но не такой осознанный

# %% [markdown]
# ### **увеличим NUM_EPOCHS_PER_ITERATION c 1 до 10 в 1 итерации**

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential


# построчное чтение из примера с текстом 
with open("wells_war_of_the_worlds.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 1 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 10
NUM_PREDS_PER_EPOCH = 100


# Create a super simple recurrent neural network. There is one recurrent
# layer that produces an embedding of size HIDDEN_SIZE from the one-hot
# encoded input layer. This is followed by a Dense fully-connected layer
# across the set of possible next characters, which is converted to a
# probability score via a standard softmax activation with a multi-class
# cross-entropy loss function linking the prediction to the one-hot
# encoding character label.

'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой. За ним последует полносвязный слой связанный с набором возможных следующих символов, которые конвертированы в вероятностные результаты через стандартную softmax активацию с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''

model = Sequential()
model.add(
    LSTM(  # вы можете изменить эту часть на GRU, LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# ==================================================
# Итерация #: 0
# Epoch 1/10
# 2643/2643 [==============================] - 85s 31ms/step - loss: 2.4923
# Epoch 2/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.8930
# Epoch 3/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.7142
# Epoch 4/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.6052
# Epoch 5/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.5304
# Epoch 6/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.4807
# Epoch 7/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.4439
# Epoch 8/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.4081
# Epoch 9/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.3758
# Epoch 10/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.3509
# Генерация из посева: reed to my
# reed to my brother seemed to the streets of the common to the streets of the common to the streets of the comm

# %% [markdown]
# ### текст стал заметно более осознанным на еще 1 фразу, но еще не достаточно

# %% [markdown]
# ### **Увеличим кол-во итераций до 25**

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential


# построчное чтение из примера с текстом 
with open("wells_war_of_the_worlds.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 128, 128
NUM_ITERATIONS = 25 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 10
NUM_PREDS_PER_EPOCH = 100


# Create a super simple recurrent neural network. There is one recurrent
# layer that produces an embedding of size HIDDEN_SIZE from the one-hot
# encoded input layer. This is followed by a Dense fully-connected layer
# across the set of possible next characters, which is converted to a
# probability score via a standard softmax activation with a multi-class
# cross-entropy loss function linking the prediction to the one-hot
# encoding character label.

'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой. За ним последует полносвязный слой связанный с набором возможных следующих символов, которые конвертированы в вероятностные результаты через стандартную softmax активацию с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''

model = Sequential()
model.add(
    LSTM(  # вы можете изменить эту часть на GRU, LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# ==================================================
# Итерация #: 0
# Epoch 1/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 2.4904
# Epoch 2/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.8959
# Epoch 3/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.7230
# Epoch 4/10
# 2643/2643 [==============================] - 81s 30ms/step - loss: 1.6085
# Epoch 5/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.5382
# Epoch 6/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.4810
# Epoch 7/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.4417
# Epoch 8/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.4091
# Epoch 9/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.3802
# Epoch 10/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.3607
# Генерация из посева: head, terr
# head, terrible that the trees and the trees and the trees and the trees and the trees and the trees and the tr==================================================
# Итерация #: 1
# Epoch 1/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.3417
# Epoch 2/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.3243
# Epoch 3/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.3090
# Epoch 4/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.2955
# Epoch 5/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.2831
# Epoch 6/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.2716
# Epoch 7/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.2610
# Epoch 8/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.2519
# Epoch 9/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.2420
# Epoch 10/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.2338
# Генерация из посева: ts machine
# ts machine that the thing of the houses and station and the thing of the houses and station and the thing of t==================================================
# Итерация #: 2
# Epoch 1/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.2262
# Epoch 2/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.2187
# Epoch 3/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.2116
# Epoch 4/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.2056
# Epoch 5/10
# 2643/2643 [==============================] - 83s 32ms/step - loss: 1.1989
# Epoch 6/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.1927
# Epoch 7/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.1870
# Epoch 8/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.1815
# Epoch 9/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.1765
# Epoch 10/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.1710
# Генерация из посева: to face th
# to face that staring at the same time the stream of the streets of the heat-ray and the stream of the streets ==================================================
# Итерация #: 3
# Epoch 1/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.1663
# Epoch 2/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.1615
# Epoch 3/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.1572
# Epoch 4/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.1521
# Epoch 5/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.1487
# Epoch 6/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.1447
# Epoch 7/10
# 2643/2643 [==============================] - 81s 30ms/step - loss: 1.1404
# Epoch 8/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.1370
# Epoch 9/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.1332
# Epoch 10/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.1293
# Генерация из посева:  to the ch
#  to the charred and stood upon the streets and the streets and the streets and the streets and the streets and==================================================
# Итерация #: 4
# Epoch 1/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.1263
# Epoch 2/10
# 2643/2643 [==============================] - 81s 30ms/step - loss: 1.1228
# Epoch 3/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.1192
# Epoch 4/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.1167
# Epoch 5/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.1131
# Epoch 6/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.1104
# Epoch 7/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.1082
# Epoch 8/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.1052
# Epoch 9/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.1025
# Epoch 10/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0998
# Генерация из посева: heir best
# heir best and drink and fight the confusion of the stars were staring in the stars were staring in the stars w==================================================
# Итерация #: 5
# Epoch 1/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0975
# Epoch 2/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0949
# Epoch 3/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0931
# Epoch 4/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0906
# Epoch 5/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0885
# Epoch 6/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0860
# Epoch 7/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.0840
# Epoch 8/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0821
# Epoch 9/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0800
# Epoch 10/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0781
# Генерация из посева: scouts who
# scouts who were all this time i saw the martians are they were staring to the station and staring at the stran==================================================
# Итерация #: 6
# Epoch 1/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0760
# Epoch 2/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0746
# Epoch 3/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0727
# Epoch 4/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0710
# Epoch 5/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0695
# Epoch 6/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0678
# Epoch 7/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0660
# Epoch 8/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0652
# Epoch 9/10
# 2643/2643 [==============================] - 79s 30ms/step - loss: 1.0629
# Epoch 10/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.0613
# Генерация из посева: eary but r
# eary but redorment that it was a man in a moment i had the fugitives and still into the streets of the martian==================================================
# Итерация #: 7
# Epoch 1/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0598
# Epoch 2/10
# 2643/2643 [==============================] - 81s 30ms/step - loss: 1.0582
# Epoch 3/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0577
# Epoch 4/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0558
# Epoch 5/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0545
# Epoch 6/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.0537
# Epoch 7/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.0519
# Epoch 8/10
# 2643/2643 [==============================] - 81s 30ms/step - loss: 1.0507
# Epoch 9/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0496
# Epoch 10/10
# 2643/2643 [==============================] - 81s 30ms/step - loss: 1.0486
# Генерация из посева: most of it
# most of its must be the beginning to go on, it is still to the towing path cloud in the stars were staring at ==================================================
# Итерация #: 8
# Epoch 1/10
# 2643/2643 [==============================] - 80s 30ms/step - loss: 1.0472
# Epoch 2/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0461
# Epoch 3/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0453
# Epoch 4/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0441
# Epoch 5/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0430
# Epoch 6/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0415
# Epoch 7/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0411
# Epoch 8/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0395
# Epoch 9/10
# 2643/2643 [==============================] - 83s 32ms/step - loss: 1.0386
# Epoch 10/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0378
# Генерация из посева: already ra
# already railing of the streets of the pit, and then the thing was the common towards the common towards the co==================================================
# Итерация #: 9
# Epoch 1/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0365
# Epoch 2/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0359
# Epoch 3/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0350
# Epoch 4/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0346
# Epoch 5/10
# 2643/2643 [==============================] - 86s 32ms/step - loss: 1.0330
# Epoch 6/10
# 2643/2643 [==============================] - 86s 32ms/step - loss: 1.0324
# Epoch 7/10
# 2643/2643 [==============================] - 87s 33ms/step - loss: 1.0317
# Epoch 8/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0305
# Epoch 9/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0294
# Epoch 10/10
# 2643/2643 [==============================] - 86s 32ms/step - loss: 1.0295
# Генерация из посева:  the south
#  the south--inverise horselly of the martians were struggled to my brother struggled to my brother struggled t==================================================
# Итерация #: 10
# Epoch 1/10
# 2643/2643 [==============================] - 87s 33ms/step - loss: 1.0277
# Epoch 2/10
# 2643/2643 [==============================] - 86s 33ms/step - loss: 1.0276
# Epoch 3/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0264
# Epoch 4/10
# 2643/2643 [==============================] - 86s 33ms/step - loss: 1.0258
# Epoch 5/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0248
# Epoch 6/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0242
# Epoch 7/10
# 2643/2643 [==============================] - 81s 31ms/step - loss: 1.0229
# Epoch 8/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0230
# Epoch 9/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0220
# Epoch 10/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0213
# Генерация из посева: nter the s
# nter the sunset remotes, and the common to see here and there were streets of the cylinder and talked upon the==================================================
# Итерация #: 11
# Epoch 1/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0206
# Epoch 2/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0198
# Epoch 3/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0198
# Epoch 4/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0180
# Epoch 5/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0182
# Epoch 6/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0174
# Epoch 7/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0161
# Epoch 8/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0160
# Epoch 9/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0153
# Epoch 10/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0150
# Генерация из посева: t is the t
# t is the thing was the streets of the pit sweyt and the stars were sight of the pit sweyt and the stars were s==================================================
# Итерация #: 12
# Epoch 1/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0138
# Epoch 2/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0140
# Epoch 3/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0131
# Epoch 4/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0122
# Epoch 5/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0130
# Epoch 6/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0116
# Epoch 7/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0110
# Epoch 8/10
# 2643/2643 [==============================] - 86s 33ms/step - loss: 1.0103
# Epoch 9/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0100
# Epoch 10/10
# 2643/2643 [==============================] - 83s 32ms/step - loss: 1.0094
# Генерация из посева: tion.  as
# tion.  as i did so a second martian stent and and the stream of the martians had been entagoured lights i saw ==================================================
# Итерация #: 13
# Epoch 1/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0092
# Epoch 2/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0080
# Epoch 3/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0082
# Epoch 4/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0077
# Epoch 5/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0075
# Epoch 6/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0065
# Epoch 7/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0061
# Epoch 8/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0061
# Epoch 9/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0049
# Epoch 10/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0056
# Генерация из посева: hed, for h
# hed, for he was still was all the streets that i had seen the pit was a meteoriced descriet.  i stopped at the==================================================
# Итерация #: 14
# Epoch 1/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 1.0042
# Epoch 2/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0040
# Epoch 3/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0036
# Epoch 4/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0030
# Epoch 5/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 1.0032
# Epoch 6/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0020
# Epoch 7/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0019
# Epoch 8/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 1.0012
# Epoch 9/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0014
# Epoch 10/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 1.0007
# Генерация из посева: for a time
# for a time i stood there was a strange and the curate in a spirit clossing ounder earthenen his side of the re==================================================
# Итерация #: 15
# Epoch 1/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9996
# Epoch 2/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9995
# Epoch 3/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9996
# Epoch 4/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9990
# Epoch 5/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9990
# Epoch 6/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9982
# Epoch 7/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9981
# Epoch 8/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9974
# Epoch 9/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9974
# Epoch 10/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 0.9974
# Генерация из посева: o drop the
# o drop the pine trees and suddenly the common altogether.  the streets that i had seen the common altogether. ==================================================
# Итерация #: 16
# Epoch 1/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 0.9959
# Epoch 2/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 0.9967
# Epoch 3/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 0.9957
# Epoch 4/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 0.9958
# Epoch 5/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 0.9956
# Epoch 6/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 0.9954
# Epoch 7/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 0.9943
# Epoch 8/10
# 2643/2643 [==============================] - 82s 31ms/step - loss: 0.9951
# Epoch 9/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 0.9939
# Epoch 10/10
# 2643/2643 [==============================] - 87s 33ms/step - loss: 0.9945
# Генерация из посева: mingling w
# mingling with the sun street into the streets of the martians as the sound of a martian in my mind.  the stree==================================================
# Итерация #: 17
# Epoch 1/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9936
# Epoch 2/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9933
# Epoch 3/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9934
# Epoch 4/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9928
# Epoch 5/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9925
# Epoch 6/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9924
# Epoch 7/10
# 2643/2643 [==============================] - 87s 33ms/step - loss: 0.9922
# Epoch 8/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 0.9918
# Epoch 9/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 0.9918
# Epoch 10/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 0.9908
# Генерация из посева: he evening
# he evening about the crowd in the pantry and smoke that streamer of great the darkness of the martians and the==================================================
# Итерация #: 18
# Epoch 1/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9908
# Epoch 2/10
# 2643/2643 [==============================] - 83s 31ms/step - loss: 0.9906
# Epoch 3/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9900
# Epoch 4/10
# 2643/2643 [==============================] - 88s 33ms/step - loss: 0.9905
# Epoch 5/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9901
# Epoch 6/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9899
# Epoch 7/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9898
# Epoch 8/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9895
# Epoch 9/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9887
# Epoch 10/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9887
# Генерация из посева: her to apo
# her to apor themerial neither on the common there still at my brother stood in the place was description of th==================================================
# Итерация #: 19
# Epoch 1/10
# 2643/2643 [==============================] - 87s 33ms/step - loss: 0.9885
# Epoch 2/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9881
# Epoch 3/10
# 2643/2643 [==============================] - 84s 32ms/step - loss: 0.9884
# Epoch 4/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9876
# Epoch 5/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9880
# Epoch 6/10
# 2643/2643 [==============================] - 85s 32ms/step - loss: 0.9877
# Epoch 7/10
# 2643/2643 [==============================] - 87s 33ms/step - loss: 0.9872
# Epoch 8/10
# 2643/2643 [==============================] - 90s 34ms/step - loss: 0.9870
# Epoch 9/10
# 2643/2643 [==============================] - 87s 33ms/step - loss: 0.9868
# Epoch 10/10
# 2643/2643 [==============================] - 87s 33ms/step - loss: 0.9864
# Генерация из посева: r a fighti
# r a fighting-machine to reached the sunset the trees and the steamboat and a steamed in the corner of the heat==================================================
# Итерация #: 20
# Epoch 1/10
# 2643/2643 [==============================] - 90s 34ms/step - loss: 0.9857
# Epoch 2/10
#   11/2643 [..............................] - ETA: 1:28 - loss: 0.9261

# %% [markdown]
# # Вывод: Качество возросло с учетом кол-ва итераций и кол-ва эпох, минусы длительность значительно больше

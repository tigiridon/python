# %%
#From SAV to LOVE

# %% [markdown]
# # HW № 5

# %% [markdown]
# ### Задание № 1.  В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной филтьтрации?

# %% [markdown]
# Коллаборативная фильтрация — это один из методов построения прогнозов (рекомендаций) в рекомендательных системах, использующий известные предпочтения (оценки) группы пользователей для прогнозирования неизвестных предпочтений другого пользователя. Его основное допущение состоит в следующем: те, кто одинаково оценивал какие-либо предметы в прошлом, склонны давать похожие оценки другим предметам и в будущем. Например, с помощью коллаборативной фильтрации музыкальное приложение способно прогнозировать, какая музыка понравится пользователю, имея неполный список его предпочтений (симпатий и антипатий). Прогнозы составляются индивидуально для каждого пользователя, хотя используемая информация собрана от многих участников.

# %% [markdown]
# Гибридная рекомендательная система включает в себя не только матрицу интеракций, как в коллаботавной фильтрации, а еще и контент (информацию о пользователях и товарах).

# %% [markdown]
# ### Задание 2.  Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы

# %% [markdown]
# * 1) Если пользователей и товаров очень много.
# * 2) Постоянно появляются новые товары и новые пользователи
# * 3) Можно мошенничать - в рекомендательных системах, где каждый может ставить оценки, люди могут давать позитивные оценки своим предметам и плохие своим конкурентам.
# * 4) Наличие белых ворон. К «белым воронам» относятся пользователи, чьё мнение постоянно не совпадает с большинством остальных. Из-за их уникального вкуса, им невозможно что-либо рекомендовать

# %% [markdown]
# ###  Задание №3.  Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/ Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах? Какие проблемы могут возникнуть при выводе такой модели в продакшен?

# %% [markdown]
# Предложенная hh.ru модель использует ансамблирование алгоритмов (фильтрующие модели + xgboost), к то время как на вебинаре мы рассматривали lightfm. В статье отмечано, что "Но мы очень быстро поняли: вакансии, похожие на резюме, и вакансии, на которые владельцу резюме хочется откликнуться, — далеко не одно и то же". То есть алгоритм, основанный на наблюдениях за статистиками куда нажимал конкретный пользователь после того как ему пришли рекомендации. Они сделали логирование того, какие вакансии показываются пользователям и что пользователи делают с ними дальше. Разработали систему a/b-тестов, инфраструктуру для того, чтобы с помощью машинного обучения прогнозировать вероятность отклика для пары «резюме/вакансия».

# %% [markdown]
# ### Задание № 4.  На вебинаре мы рассматривали модель LightFM (https://making.lyst.com/lightfm/docs/lightfm.html). В работе Data Scientist'а важную часть занимает research - исследование существующих архитектур и разбор научных статей, в которых они описываются. Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:
# * 1) На вебинаре я не упомянул про использование одной функции в модели. Найдите в статье описание преобразования, про которое я не упомянул. Как это преобразование влияет на обучение модели?
# #### Автор использует фукцию сигмоиды для бинарного предсказания.
# * 2) Какой датасет используют авторы?
# ### Производительность LightFM оценивают на двух наборах данных. 1 набор данных охватывают диапазон плотных данных взаимодействия, где можно ожидать, что модели MF будут работать хорошо, и разреженные данные, где модели CB, как правило, работают лучше (Перекрестная проверка).
# #### В первом эксперименте используется широко известный MovieLens 10M. Набор данных состоит примерно из 10 миллионов фильмов, оценок, присланных 71 567 пользователями на 10 681 фильм. Все фильмы описаны по жанрам и списком тегов из Геном тега. Каждая пара тегов фильма сопровождается оценкjой релевантности (от 0 до 1), обозначающая, насколько точно данный тег описывает фильм.
# #### Набор данных 2 состоит из 5953 пользователей, 44 200 вопросов и 188 865 ответов и комментариев. Каждый вопрос сопровождается одним или несколькими из 1032 уникальных тегов
# * 3) С какими моделями сравнивают LightFM? Опишите их основные идеи кратко
# #### MF: обычная матричная модель факторизации
# #### LSI-LR: контекстное ориентированная модель
# #### LSI-UP: гибридная модель
